# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulkadir2516/GMKA_Abdulkadir_Yesilkaya/blob/main/Odevi4_Python_Veri_Analizi_Egitimi__Abdulkadir_Ye%C5%9Filkaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Güney Marmara ve TRAI
# # <center> Python Veri Analizi Eğitimi
# # <center> Ödev 4

# %% [markdown]
# ### Veriyi özetleme

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 1.  3. Ders sonunda hazırladığınız 2021 ve 2022 yıllarına ait BIST30 ve EUR/USD kur değerlerini içeren bileşke tablodan sadece ayın son işgününe ait değerleri içeren bir pivot tablo üretiniz.

# %%
indirme_listesi = ["XU030.IS","EURTRY=X"]
Data = pd.DataFrame()

for i in indirme_listesi:
  data = yf.download(i, start="2021-01-01",end="2022-12-31")
  data = data["Adj Close"].rename(i)
  Data= pd.concat([Data, data], axis=1)

Data.columns =["Kapanış (TRY)", "EUR/TRY"]
Data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             Kapanış (TRY)    EUR/TRY
# 2021-01-04    1652.900024   9.105680
# 2021-01-05    1640.400024   9.088820
# 2021-01-06    1657.699951   9.081770
# 2021-01-07    1678.199951   9.006140
# 2021-01-08    1694.400024   8.998500
# ...                   ...        ...
# 2022-07-11            NaN  17.503019
# 2022-07-12            NaN  17.325560
# 2022-07-15            NaN  17.506651
# 2022-08-30            NaN  18.190140
# 2022-12-26            NaN  19.734200
#
# [521 rows x 2 columns]

# %%
Data.index = pd.to_datetime(Data.index) # convert index to datetime object
Data['ay-yıl'] = Data.index.strftime('%Y-%m') # apply strftime() method
Data
# Out:
#             Kapanış (TRY)    EUR/TRY   ay-yıl
# 2021-01-04    1652.900024   9.105680  2021-01
# 2021-01-05    1640.400024   9.088820  2021-01
# 2021-01-06    1657.699951   9.081770  2021-01
# 2021-01-07    1678.199951   9.006140  2021-01
# 2021-01-08    1694.400024   8.998500  2021-01
# ...                   ...        ...      ...
# 2022-07-11            NaN  17.503019  2022-07
# 2022-07-12            NaN  17.325560  2022-07
# 2022-07-15            NaN  17.506651  2022-07
# 2022-08-30            NaN  18.190140  2022-08
# 2022-12-26            NaN  19.734200  2022-12
#
# [521 rows x 3 columns]

# %%
Data_as = Data.pivot_table(values=["Kapanış (TRY)", "EUR/TRY"], index="ay-yıl", 
                           aggfunc= "mean")#{np.max,npmean})
Data_as
# Out:
#            EUR/TRY  Kapanış (TRY)
# ay-yıl
# 2021-01   9.014022    1656.573679
# 2021-02   8.572331    1609.850016
# 2021-03   9.142648    1558.160873
# 2021-04   9.763095    1444.454980
# 2021-05  10.161635    1509.192308
# 2021-06  10.392120    1525.222723
# 2021-07  10.172563    1475.762489
# 2021-08   9.970865    1553.447632
# 2021-09  10.051412    1526.122731
# 2021-10  10.658620    1540.635010
# 2021-11  12.088088    1827.549999
# 2021-12  15.099254    2149.891299
# 2022-01  15.263392    2220.761940
# 2022-02  15.421120    2220.479980
# 2022-03  16.043909    2352.939124
# 2022-04  15.907370    2715.142811
# 2022-05  16.447871    2705.644450
# 2022-06  17.906541    2792.090898
# 2022-07  17.707941    2649.966648
# 2022-08  18.223027    3158.577271
# 2022-09  18.126351    3619.459095
# 2022-10  18.256694    4085.866664
# 2022-11  18.922425    4944.195423
# 2022-12  19.710295    5609.485724

# %% [markdown]
# 2. Ay kırılımlı olarak ürettiğiniz tabloyu grafik olarak inceleyiniz.

# %%
Data_as["Degisim"] = Data_as["Kapanış (TRY)"].diff(1)
Data_as["D_yon"] = Data_as.Degisim.map(lambda x: "Düşen gün" if x<0 else "Yükselen gün")
Data_as["Degisim%"] = (Data_as["Degisim"]/Data_as["Kapanış (TRY)"].shift(1))
Data_as
# Out:
#            EUR/TRY  Kapanış (TRY)     Degisim         D_yon  Degisim%
# ay-yıl
# 2021-01   9.014022    1656.573679         NaN  Yükselen gün       NaN
# 2021-02   8.572331    1609.850016  -46.723663     Düşen gün -0.028205
# 2021-03   9.142648    1558.160873  -51.689144     Düşen gün -0.032108
# 2021-04   9.763095    1444.454980 -113.705892     Düşen gün -0.072974
# 2021-05  10.161635    1509.192308   64.737327  Yükselen gün  0.044818
# 2021-06  10.392120    1525.222723   16.030415  Yükselen gün  0.010622
# 2021-07  10.172563    1475.762489  -49.460234     Düşen gün -0.032428
# 2021-08   9.970865    1553.447632   77.685143  Yükselen gün  0.052641
# 2021-09  10.051412    1526.122731  -27.324901     Düşen gün -0.017590
# 2021-10  10.658620    1540.635010   14.512279  Yükselen gün  0.009509
# 2021-11  12.088088    1827.549999  286.914989  Yükselen gün  0.186232
# 2021-12  15.099254    2149.891299  322.341300  Yükselen gün  0.176379
# ...

# %%
fig_1 =px.bar(Data_as,x=Data_as.index, y="Degisim%",color="D_yon",
       color_discrete_map={"Düşen gün": "red", "Yükselen gün": "green"},
       text_auto=".0%")
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3. Ders sonunda hazırladığınız 2021 ve 2022 yıllarına ait BIST30 ve EUR/USD kur değerlerini içeren bileşke tablodan sadece ayın son işgününe ait değerleri içeren bir tabloyu bir de resample yöntemi ile üretiniz.

# %%
Data_as2 = Data[["Kapanış (TRY)","EUR/TRY"]].resample("BM").mean()
Data_as2["ay-yıl"] = Data["ay-yıl"].resample("BM", convention="end").asfreq()
Data_as2.index= Data_as2["ay-yıl"]
Data_as2 = Data_as2.drop("ay-yıl", axis=1)
Data_as2
# Out:
#          Kapanış (TRY)    EUR/TRY
# ay-yıl
# 2021-01    1656.573679   9.014022
# 2021-02    1609.850016   8.572331
# 2021-03    1558.160873   9.142648
# 2021-04    1444.454980   9.763095
# 2021-05    1509.192308  10.161635
# 2021-06    1525.222723  10.392120
# 2021-07    1475.762489  10.172563
# 2021-08    1553.447632   9.970865
# 2021-09    1526.122731  10.051412
# 2021-10    1540.635010  10.658620
# 2021-11    1827.549999  12.088088
# 2021-12    2149.891299  15.099254
# 2022-01    2220.761940  15.263392
# 2022-02    2220.479980  15.421120
# 2022-03    2352.939124  16.043909
# 2022-04    2715.142811  15.907370
# 2022-05    2705.644450  16.447871
# 2022-06    2792.090898  17.906541
# 2022-07    2649.966648  17.707941
# 2022-08    3158.577271  18.223027
# 2022-09    3619.459095  18.126351
# 2022-10    4085.866664  18.256694
# 2022-11    4944.195423  18.922425
# 2022-12    5609.485724  19.710295

# %%
Data_as2["Degisim"] = Data_as2["Kapanış (TRY)"].diff(1)
Data_as2["D_yon"] = Data_as2.Degisim.map(lambda x: "Düşen gün" if x<0 else "Yükselen gün")
Data_as2["Degisim%"] = (Data_as2["Degisim"]/Data_as2["Kapanış (TRY)"].shift(1))
Data_as2
# Out:
#          Kapanış (TRY)    EUR/TRY     Degisim         D_yon  Degisim%
# ay-yıl
# 2021-01    1656.573679   9.014022         NaN  Yükselen gün       NaN
# 2021-02    1609.850016   8.572331  -46.723663     Düşen gün -0.028205
# 2021-03    1558.160873   9.142648  -51.689144     Düşen gün -0.032108
# 2021-04    1444.454980   9.763095 -113.705892     Düşen gün -0.072974
# 2021-05    1509.192308  10.161635   64.737327  Yükselen gün  0.044818
# 2021-06    1525.222723  10.392120   16.030415  Yükselen gün  0.010622
# 2021-07    1475.762489  10.172563  -49.460234     Düşen gün -0.032428
# 2021-08    1553.447632   9.970865   77.685143  Yükselen gün  0.052641
# 2021-09    1526.122731  10.051412  -27.324901     Düşen gün -0.017590
# 2021-10    1540.635010  10.658620   14.512279  Yükselen gün  0.009509
# 2021-11    1827.549999  12.088088  286.914989  Yükselen gün  0.186232
# 2021-12    2149.891299  15.099254  322.341300  Yükselen gün  0.176379
# ...

# %% [markdown]
# 4. Resample yöntemi ile ürettiğiniz tabloyu grafik olarak inceleyiniz. 2. adımda elde ettiğiniz grafik ile karşılaştırarak yorumlayınız.

# %%
fig_2 =px.bar(Data_as2,x=Data_as2.index, y="Degisim%",color="D_yon",
       color_discrete_map={"Düşen gün": "red", "Yükselen gün": "green"},
       text_auto=".0%")
fig_1.show()
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Önceki yapıda resample kullanırken son günü baz alarak yapılıyordu ve bunun sonucunda ayın songünü işlem yapılmamış boş değerler ortaya çıkıyordu ve haliyle grafiklerde farklıydı şimdi ise o ay içerisinde değerlerin ortalamsı ile hesaplama yapılıyor bu sayede boş veri oluşmuyor ve grafikler gözüktüğü üzere aynı
